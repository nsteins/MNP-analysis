# %%
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8


import numpy as np
import matplotlib.pyplot as plt

# %%
p1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak power calibration direct')
plt.plot(p1[:,1],p1[:,2])

p2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak power calibration through switches')
plt.plot(p2[:,1],p2[:,2])

# %%
plt.plot(p1[:,1],p2[:,2]+4,'b.-')

# %%
np.savetxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak plus switches power calibration',np.column_stack((p1[:,1],p2[:,2]+4)))

# %%
p3 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak power calibration through switches leveled 0dbm')
plt.plot(p3[:,1],p3[:,2])
p4 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak power calibration through switches leveled -4dbm')
plt.plot(p4[:,1],p4[:,2]+3)

# %%
p1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak power calibration through switches high res')
plt.plot(p1[:,1],p1[:,2],'b.-')

# %%
np.savetxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak plus switches power calibration high res',np.column_stack((p1[:,1],p1[:,2])))

# %%
p1.shape
# Out:
# (679L, 3L)

# %%
p3 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak power calibration through amp leveled -4dbm high res')
plt.plot(p3[:,1],4-p3[:,2])
p4 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak power calibration through switches leveled -4dbm')
plt.plot(p4[:,1],p4[:,2]+p3[:,2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-d9f867d13a1d> in <module>()
#       2 plt.plot(p3[:,1],4-p3[:,2])
#       3 p4 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak power calibration through switches leveled -4dbm')
# ----> 4 plt.plot(p4[:,1],p4[:,2]+p3[:,2])
#
# ValueError: operands could not be broadcast together with shapes (84,) (679,)

# %%
np.savetxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak plus switches and amp power calibration high res',np.column_stack((p1[:,1],p1[:,2]-(4-p3[:,2]))))

# %%
p5 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\Windfreak power calibration through amp leveled -4dbm 2')
plt.plot(p5[:,1],24+p5[:,2],'bo-')

# %%
p6 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\MNP CPW transmission')
plt.plot(p6[:,1],24+p6[:,2],'bo-')
p7 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-26-16\ND CPW transmission')
plt.plot(p7[:,1],24+p7[:,2],'go-')

# %%
p7 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\12-16-16\MNP 11-3-B on CPW transmission')
plt.plot(p7[:,1],24+p7[:,2],'go-')

# %%
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8
rcParams.update({'font.size':16})

plt.plot(p6[:,1],p6[:,2]-p5[:,2],'ko-')
plt.xlabel("Frequency",fontsize = 16)
plt.ylabel("$S_{21}$ (dBm)",fontsize = 16)
