# %%
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8
from NV import *

def b(f):
    return (f-2.865E9)/28E6

# %%
odmr0 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 2mW scan 3 x61 y99 T98 th36 d8.2 ODMR 2 B0V')
odmr1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 2mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V after')
odmr2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 2mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V after 2')
odmr3 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 2mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V after 3')

plt.plot(b(odmr1[1:,0]),odmr1[1:,1],'g.-')
plt.plot(b(odmr2[1:,0]),odmr2[1:,1],'k.-')
plt.plot(b(odmr3[1:,0]),odmr3[1:,1],'b.-')
plt.plot(b(odmr4[1:,0]),odmr4[1:,1],'r.-')

# %%
odmr4 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 12mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V 4')
odmr5 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 12mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V 5')
odmr6 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 12mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V 6')
odmr7 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 12mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V 7')
odmr8 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 12mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V 8')


plt.plot(b(odmr4[1:,0]),odmr4[1:,1],'k.-')
plt.plot(b(odmr5[1:,0]),odmr5[1:,1],'b.-')
plt.plot(b(odmr6[1:,0]),odmr6[1:,1],'r.-')
plt.plot(b(odmr7[1:,0]),odmr7[1:,1],'g.-')

# %%
rcParams['lines.linewidth'] = 2

plt.plot(b(odmr0[1:,0]),odmr0[1:,1],'.-',color=plt.cm.nipy_spectral(1/9.0))
plt.plot(b(odmr1[1:,0]),odmr1[1:,1],'.-',color=plt.cm.nipy_spectral(2/9.0))
plt.plot(b(odmr2[1:,0]),odmr2[1:,1],'.-',color=plt.cm.nipy_spectral(3/9.0))
plt.plot(b(odmr3[1:,0]),odmr3[1:,1],'.-',color=plt.cm.nipy_spectral(4/9.0))
plt.plot(b(odmr4[1:,0]),odmr4[1:,1],'.-',color=plt.cm.nipy_spectral(5/9.0))
plt.plot(b(odmr4[1:,0]),odmr4[1:,1],'.-',color=plt.cm.nipy_spectral(6/9.0))
plt.plot(b(odmr5[1:,0]),odmr5[1:,1],'.-',color=plt.cm.nipy_spectral(7/9.0))
plt.plot(b(odmr6[1:,0]),odmr6[1:,1],'.-',color=plt.cm.nipy_spectral(8/9.0))
plt.plot(b(odmr7[1:,0]),odmr7[1:,1],'.-',color=plt.cm.nipy_spectral(9/9.0))
plt.xlim([-6,6])
# Out:
# (-6, 6)

# %%
from __future__ import division
odmrs = [odmr0,odmr1,odmr2,odmr3,odmr4,odmr5,odmr6,odmr7,odmr8]
opt_arr = np.zeros((len(odmrs),2))

for i,odmr in enumerate(odmrs):
    freq = odmr[1:,0]
    O = odmr[1:,1]
    opt, cov = curve_fit(ODMRfit,freq,O,p0=(-4E8,freq[np.argmin(O)],1E7,-4E8,2.87E9*2-freq[np.argmin(O)],1E7),maxfev=2500)
    opt_arr[i,:] = opt[np.array([1,4])]
    #plt.plot(freq,O,'o',color=plt.cm.nipy_spectral(i/len(odmrs)))
    plt.plot(freq,ODMRfit(freq,*opt),'-',color=plt.cm.nipy_spectral(i/len(odmrs)))
    
plt.xlim([2.7E9,3.1E9])
# Out:
# (2700000000.0, 3100000000.0)

# %%
plt.plot(range(opt_arr.shape[0]),(2.865E9-np.max(opt_arr,axis=1))/-28E6,'ko:')

# %%
rcParams.keys()
# Out:
# [u'agg.path.chunksize',
#  u'animation.avconv_args',
#  u'animation.avconv_path',
#  u'animation.bitrate',
#  u'animation.codec',
#  u'animation.convert_args',
#  u'animation.convert_path',
#  u'animation.ffmpeg_args',
#  u'animation.ffmpeg_path',
#  u'animation.frame_format',
#  u'animation.html',
#  u'animation.mencoder_args',
#  u'animation.mencoder_path',
#  u'animation.writer',
#  u'axes.axisbelow',
#  u'axes.edgecolor',
#  u'axes.facecolor',
#  u'axes.formatter.limits',
#  u'axes.formatter.use_locale',
#  u'axes.formatter.use_mathtext',
#  u'axes.formatter.useoffset',
#  u'axes.grid',
#  u'axes.grid.axis',
#  u'axes.grid.which',
#  u'axes.hold',
#  u'axes.labelcolor',
#  u'axes.labelpad',
#  u'axes.labelsize',
#  u'axes.labelweight',
#  u'axes.linewidth',
#  u'axes.prop_cycle',
#  u'axes.spines.bottom',
#  u'axes.spines.left',
#  u'axes.spines.right',
#  u'axes.spines.top',
#  u'axes.titlesize',
#  u'axes.titleweight',
#  u'axes.unicode_minus',
#  u'axes.xmargin',
# ...

# %%
trace1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 2mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V after time trace.txt',
                   skiprows=1)
plt.plot(trace1[:,0]*5,trace1[:,1],'ko:')

# %%
trace1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 2mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V 2 after time trace.txt',
                   skiprows=1)
plt.plot(trace1[:,0]*5,trace1[:,1],'ko:')

# %%
trace1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\1-30-17\MNP 11-3-C 12mW scan 3 x61 y99 T98 th-36 d-8.2 ODMR 2 B0V 5 time trace after.txt',
                   skiprows=1)
plt.plot(trace1[:,0]*5,trace1[:,1],'ko:')
