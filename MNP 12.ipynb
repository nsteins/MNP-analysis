# %%
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8
from NV import *

def T1Fit(t,I_inf,C_m,T_m,C_1,T_1):
         return I_inf * (1 - C_m*np.exp(-t/T_m) + C_1*np.exp(-t/T_1))

# %%
T1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 3 x160 y133 rotor sweep')
T1[:,1] -= 2180
OrientPol(T1,False)
# Out:
# Phi: -10.807320 +/- 0.741180
# Theta: 49.518960 or +/- 0.639777
# Phi(naive): -13.146000
# Theta(naive): 53.726644

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 2 multidot T1 x173 y121 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 2 multidot T1 x173 y121 T1 7200 sec  Pulse Seq')
time = time+20
#T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [ -1.27914749e+02  -3.34668834e-01   3.63134514e+02  -1.25736204e+00
#    2.72456200e+04]
# C:\Users\Ouyang Group\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: RuntimeWarning: overflow encountered in exp

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 2 multidot T1 x48 y124 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 2 multidot T1 x48 y124 T1 7200 sec  Pulse Seq')
time = time+20
#T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [   7.79780583   60.88813048  696.50237525   59.85425183  714.24720841]
# C:\Users\Ouyang Group\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: RuntimeWarning: overflow encountered in exp

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 2 multidot T1 x105 y134 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 2 multidot T1 x105 y134 T1 7200 sec  Pulse Seq')
time = time+20
#T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [  1.45496345e-04   1.78187029e+06   2.21189158e+02   1.82170903e+06
#    3.12765978e+03]

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 2 multidot T1 x193 y85 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 2 multidot T1 x193 y85 T1 7200 sec  Pulse Seq')
time = time+20
#T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [ -5.00123636e+01  -4.73926745e-01   2.86150675e+02  -1.58009718e+00
#    4.25414849e+03]

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 2 multidot T1 x3 y135 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 2 multidot T1 x3 y135 T1 7200 sec  Pulse Seq')
time = time+20
#T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [ -6.31279073e+02  -4.93252634e-01   1.97933963e+02  -1.48465277e+00
#    1.13905967e+04]
# C:\Users\Ouyang Group\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: RuntimeWarning: overflow encountered in exp

# %%
time,rabi0 = EPR_NoRef(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 3 x160 y133 T-10 d5 th53 B0.5V rabi *[0-9]',
              r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 3 x160 y133 T-10 d5 th53 B0.5V rabi Pulse Seq')
rabi0 = 100*rabi0/np.mean(rabi0)
opt0,cov0 = curve_fit(RabiFit,time[1:],rabi0[1:],maxfev=5500,p0=(100,4E-3,0,10,100))
t = np.arange(0,np.max(time),1)
plt.plot(time,rabi0,'ko:')
plt.plot(time,RabiFit(time,*opt0),'b-')
print opt0
# Out:
# [  1.24095375e+01   6.35828329e-03   3.74411652e+00   3.82471860e+02
#    1.00331039e+02]

# %%
def T2Fit(t,C,tau,D):
    return C*np.exp(-t/tau)+D

time,hahn1 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 3 x160 y133 T-10 d5 th53 B0.5V hahn *[0-9]',
              r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 3 x160 y133 T-10 d5 th53 B0.5V hahn Pulse Seq')
hahn1 = hahn1-np.min(hahn1)
opt0,cov0 = curve_fit(T2Fit,time[1:],hahn1[1:],maxfev=5500,p0=(10000,1600,-np.min(hahn1)))
t = np.arange(10,np.max(time),1)
plt.plot(t,T2Fit(t,*opt0),'b-')
plt.plot(time[1:],hahn1[1:],'ko:')
print opt0
print (np.mean(hahn1),1/np.sqrt(np.mean(hahn1)),np.std(hahn1[-20:])/np.mean(hahn1[-20:]))
# Out:
# [ 216.4162031   471.39617815   19.9427816 ]
# (34.652423469387756, 0.16987645655144726, 0.27993280072803745)

# %%
T1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 4 x169 y113  Rotor Sweep')
T1[:,1] -= 2180
OrientPol(T1,False)
# Out:
# Phi: 81.318989 +/- 1.181470
# Theta: 28.180689 or +/- 0.558816
# Phi(naive): 87.978000
# Theta(naive): 31.762483

# %%
time,rabi0 = EPR_NoRef(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 3 x117 y118 t80 th31 d8.8 B0.5V rabi *[3-9]',
              r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 3 x117 y118 t80 th31 d8.8 B0.5V rabi Pulse Seq')
rabi0 = 100*rabi0/np.mean(rabi0)
#opt0,cov0 = curve_fit(RabiFit,time[1:],rabi0[1:],maxfev=5500,p0=(100,4E-3,0,10,100))
t = np.arange(0,np.max(time),1)
plt.plot(time,rabi0,'ko:')
#plt.plot(time,RabiFit(time,*opt0),'b-')
#print opt0

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 9 multi T1  x48 y149 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 9 multi T1  x48 y149 T1 7200 sec  Pulse Seq')
time = time+20
T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [  1.34724264e+01   9.49128130e+00   2.08050552e+02   2.02187924e+01
#    1.47230075e+04]

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 9 multi T1  x186 y97 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 9 multi T1  x186 y97 T1 7200 sec  Pulse Seq')
time = time+20
T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [    29.17478752     16.33183712    198.82484069     29.98301957
#   12519.1855951 ]

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 9 multi T1  x95 y97 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 9 multi T1  x95 y97 T1 7200 sec  Pulse Seq')
time = time+20
T0 = T0 - np.min(T0)
#opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
#plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [  1.34724264e+01   9.49128130e+00   2.08050552e+02   2.02187924e+01
#    1.47230075e+04]

# %%
T1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 11 x68 y134 rotor sweep')
T1[:,1] -= 2180
OrientPol(T1,False)
# Out:
# Phi: 39.950180 +/- 0.829835
# Theta: 25.777468 or +/- 0.367683
# Phi(naive): 47.528000
# Theta(naive): 27.692721

# %%
time,rabi0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 11 x68 y134 t40 th25 d10.2 B0.5V 2 rabi *[0-9]',
              r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 11 x68 y134 t40 th25 d10.2 B0.5V 2 rabi Pulse Seq')
#rabi0 = 100*rabi0/np.mean(rabi0)
opt0,cov0 = curve_fit(RabiFit,time[1:],rabi0[1:],maxfev=5500,p0=(100,4E-3,0,10,100))
t = np.arange(0,np.max(time),1)
plt.plot(time,rabi0,'ko:')
plt.plot(time,RabiFit(time,*opt0),'b-')
print opt0
# Out:
# [  1.34161596e+02   4.96818998e-03  -1.40184647e-01   2.92505710e+02
#    5.03471672e+01]

# %%
def T2Fit(t,C,tau,D):
    return C*np.exp(-t/tau)+D
time,hahn1 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 11 x68 y134 t40 th25 d10.2 B0.5V 2 hahn *[0-9]',
              r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 11 x68 y134 t40 th25 d10.2 B0.5V 2 hahn Pulse Seq')
hahn1 = hahn1-np.min(hahn1)
opt0,cov0 = curve_fit(T2Fit,time[1:],hahn1[1:],maxfev=5500,p0=(10000,1600,-np.min(hahn1)))
t = np.arange(10,np.max(time),1)
plt.plot(t,T2Fit(t,*opt0),'b-')
plt.plot(time[1:],hahn1[1:],'ko:')
print opt0
print (np.mean(hahn1),1/np.sqrt(np.mean(hahn1)),np.std(hahn1[-20:])/np.mean(hahn1[-20:]))
# Out:
# [ 101.41094448  597.11286207   30.21161257]
# (39.19345238095238, 0.15973248195302203, 0.38925089678818547)

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 multi T1  x73 y160 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 multi T1  x73 y160 T1 7200 sec  Pulse Seq')
time = time+20
T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [  5.43154636e+01   1.60925148e+00   4.03333255e+02   4.58138122e-01
#    5.86700932e+04]

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 multi T1  x163 y111 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 multi T1  x163 y111 T1 7200 sec  Pulse Seq')
time = time+20
T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [  7.42961657e+01   1.91187263e+00   2.59924916e+02   3.40485739e+00
#    1.68779655e+04]

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 multi T1  x149 y116 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 multi T1  x149 y116 T1 7200 sec  Pulse Seq')
time = time+20
T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [  4.42852406e+02   2.08862074e+00   3.05489872e+02   7.55115899e-01
#    4.82095826e+04]

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 multi T1  x75 y72 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 multi T1  x75 y72 T1 7200 sec  Pulse Seq')
time = time+20
T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,3600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [  1.39107192e+02   5.21931302e+00   1.70777547e+02   1.28719248e+01
#    2.55424168e+04]
# C:\Users\Ouyang Group\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: RuntimeWarning: overflow encountered in exp

# %%
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 multi T1  x196 y109 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 multi T1  x196 y109 T1 7200 sec  Pulse Seq')
time = time+20
T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,30600))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [  3.21488343e+01   3.16986230e+00   2.36928569e+02   4.50015570e+00
#    3.67506848e+04]

# %%
T1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 x92 y133 rotor sweep')
T1[:,1] -= 2180
OrientPol(T1,False)
# Out:
# Phi: 16.144535 +/- 0.714586
# Theta: 36.838177 or +/- 0.443162
# Phi(naive): 7.079000
# Theta(naive): 43.253070

# %%
def EPR(EPRfiles,Pfiles):
    files = glob.glob(EPRfiles)
    pseq = np.loadtxt(Pfiles)
    d_sum = np.zeros((pseq.shape[0],))
    l = pseq.shape[0]
    for f in files:
        epr = np.loadtxt(f)
        diff = (epr[0:,0]-epr[0:,1])
        diff[np.isinf(diff)] = 0
        diff = np.nan_to_num(diff)
        diff.resize(((diff.shape[0]- (diff.shape[0] % l)),1))
        diff = np.reshape(diff,(pseq.shape[0],-1),order='F')
        d_sum += np.mean(diff,axis=1)
        
    return pseq,d_sum/len(files)



time,rabi0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 x92 y133 t16 d8.2 th37 B0.5V rabi *[0-9]',
              r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 x92 y133 t16 d8.2 th37 B0.5V rabi Pulse Seq')
rabi0 = 100*rabi0/np.mean(rabi0)
opt0,cov0 = curve_fit(RabiFit,time[1:],rabi0[1:],maxfev=5500,p0=(100,4E-3,0,10,100))
t = np.arange(0,np.max(time),1)
plt.plot(time,rabi0,'ko:')
plt.plot(time,RabiFit(time,*opt0),'b-')
print opt0
# Out:
# [  1.08973857e+02   1.05764649e-02  -2.92618072e+00   7.09231319e+02
#    1.01357163e+02]

# %%
def T2Fit(t,C,tau,D):
    return C*np.exp(-t/tau)+D
time,hahn1 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 x92 y133 t16 d8.2 th37 B0.5V hahn *[2-9]',
              r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 x92 y133 t16 d8.2 th37 B0.5V hahn Pulse Seq')
hahn1 = hahn1-np.min(hahn1)
opt0,cov0 = curve_fit(T2Fit,time[1:],hahn1[1:],maxfev=5500,p0=(10000,1600,-np.min(hahn1)))
t = np.arange(10,np.max(time),1)
plt.plot(t,T2Fit(t,*opt0),'b-')
plt.plot(time[1:],hahn1[1:],'ko:')
print opt0
print (np.mean(hahn1),1/np.sqrt(np.mean(hahn1)),np.std(hahn1[-20:])/np.mean(hahn1[-20:]))
# Out:
# [  28.77959337  612.02454472   35.256483  ]
# (37.825456498388824, 0.16259527129005336, 0.2057136685711991)

# %%
def T2Fit(t,C,tau,D):
    return C*np.exp(-t/tau)+D
time,hahn1 = EPR(r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 x92 y133 t16 d8.2 th37 B0.5V 2 hahn *[2-9]',
              r'C:\Users\Ouyang Group\Documents\Data\2-7-17\MNP 12-1 2mW scan 15 x92 y133 t16 d8.2 th37 B0.5V 2 hahn Pulse Seq')
hahn1 = hahn1-np.min(hahn1)
opt0,cov0 = curve_fit(T2Fit,time[1:],hahn1[1:],maxfev=5500,p0=(10000,1600,-np.min(hahn1)))
t = np.arange(10,np.max(time),1)
plt.plot(t,T2Fit(t,*opt0),'b-')
plt.plot(time[1:],hahn1[1:],'ko:')
print opt0
print (np.mean(hahn1),1/np.sqrt(np.mean(hahn1)),np.std(hahn1[-20:])/np.mean(hahn1[-20:]))
# Out:
# [  40.5325166   670.01837146    7.59238339]
# (12.022297808012096, 0.28840730683826982, 0.62250492339042907)
