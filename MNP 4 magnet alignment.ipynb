# %%
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8
from NV import *

# %%
d = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-17-16\MNP 4 on CPW 5mW scan 1 x173 y118 T25 B1.5V position sweep 2')
plt.plot(d[:,1]/np.cos(25*np.pi/180),d[:,4],'ko:')

# %%
d = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-17-16\MNP 4 on CPW 5mW scan 1 x173 y118 T25 B1.5V position sweep 4')
plt.plot(np.linspace(0,50,num=d[:,0].shape[0]),d[:,4],'ko:')

# %%
np.linspace(0,50,num=d[:,0].shape[0])
# Out:
# array([  0.        ,   1.02040816,   2.04081633,   3.06122449,
#          4.08163265,   5.10204082,   6.12244898,   7.14285714,
#          8.16326531,   9.18367347,  10.20408163,  11.2244898 ,
#         12.24489796,  13.26530612,  14.28571429,  15.30612245,
#         16.32653061,  17.34693878,  18.36734694,  19.3877551 ,
#         20.40816327,  21.42857143,  22.44897959,  23.46938776,
#         24.48979592,  25.51020408,  26.53061224,  27.55102041,
#         28.57142857,  29.59183673,  30.6122449 ,  31.63265306,
#         32.65306122,  33.67346939,  34.69387755,  35.71428571,
#         36.73469388,  37.75510204,  38.7755102 ,  39.79591837,
#         40.81632653,  41.83673469,  42.85714286,  43.87755102,
#         44.89795918,  45.91836735,  46.93877551,  47.95918367,
#         48.97959184,  50.        ])

# %%
d = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-17-16\MNP 4 on CPW 5mW scan 1 x173 y118 T25 B1.5V position sweep 5')
plt.plot(np.linspace(0,15,num=d[:,0].shape[0]),d[:,4],'ko:')

# %%
d = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-17-16\MNP 4 on CPW 5mW scan 1 x173 y118 T25 B1.5V position sweep 6')
plt.plot(d[:,1]/np.cos(10.2*np.pi/180),d[:,4],'ko:')

# %%
d = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-17-16\MNP 4 on CPW 5mW scan 1 x173 y118 T25 B1.5V position sweep 7')
plt.plot(np.linspace(0,50,num=d[:,0].shape[0]),d[:,4],'ko:')

# %%
d = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-17-16\MNP 4 on CPW 5mW scan 1 x173 y118 T10.2 B sweep 8')
d2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-17-16\MNP 4 on CPW 5mW scan 1 x173 y118 T10.2 B sweep 16')

plt.plot(d[:,0],d[:,1],'ko:')
plt.plot(d2[:,0],d2[:,1],'ro:')

# %%
d = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-17-16\MNP 4 on CPW 5mW scan 1 x173 y118 T25 B2.1V position sweep 10')
plt.plot(np.linspace(5,8,num=d[:,0].shape[0]),d[:,4],'ko:')

# %%
d = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-17-16\MNP 4 on CPW 5mW scan 1 x173 y118 T25 B2.1V position sweep 14')
plt.plot(np.linspace(6,12,num=d[:,0].shape[0]),d[:,4],'ko:')

# %%
d = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-17-16\MNP 4 on CPW 5mW scan 1 x173 y118 T25 B2.1V position sweep 15')
plt.plot(np.linspace(6,7,num=d[:,0].shape[0]),d[:,4],'ko:')

# %%
d = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-19-16\MNP 4 on CPW 5mW B Sweep PL')
d2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\10-19-16\MNP 4 on CPW 5mW B Sweep PL 2')
plt.plot(d[:,0],d[:,1],'ko:')
plt.plot(d2[:,0],d2[:,1],'ko:')
