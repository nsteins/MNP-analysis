# %%
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8


import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-28-16\freq and power sweep to amp')

# %%
plt.plot(t[:,0],t[:,1],'k.:')

# %%
plt.plot(t[2:,0],t[2:,2],'k.:')

# %%
t25 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-28-16\freq and power sweep to amp power sweep')
t1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-28-16\freq and power sweep to amp power sweep 1G')
t2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-28-16\freq and power sweep to amp power sweep 2G')
t3 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-28-16\freq and power sweep to amp power sweep 3G')
t4 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-28-16\freq and power sweep to amp power sweep 4G')

plt.plot(t4[20:,0],t4[20:,2],'y.:')
plt.plot(t3[20:,0],t3[20:,2],'g.:')
plt.plot(t25[2:,0],t25[2:,2],'b.:')
plt.plot(t2[2:,0],t2[2:,2],'r.:')
plt.plot(t1[2:,0],t1[2:,2],'k.:')
#plt.xlim([6,7])
#plt.ylim([-10,10])

# %%
v = -2
print t1[(np.abs(t1[:,2] - v)).argmin(),0]
print t2[(np.abs(t2[:,2] - v)).argmin(),0]
print t3[(np.abs(t3[:,2] - v)).argmin(),0]
print t4[(np.abs(t4[:,2] - v)).argmin(),0]
# Out:
# 5.96
# 6.263
# 6.364
# 6.768

# %%
import pandas as pd

# %%
df = pd.read_table(r'C:\Users\Ouyang Group\Documents\Data\7-30-16\MW linear power sweep two power high res')

# %%
o = np.empty((np.unique(df.v1).shape[0],5))
for i,v in enumerate(np.unique(df.v1)):
    plt.plot(df[df.v1==v].v2,df[df.v1==v].p,'o:')
    o[i,0] = v
    o[i,1] = df[df.v1==v].v2.values[(np.abs(df[df.v1==v].p.values - -4)).argmin()]
    o[i,2] = df[df.v1==v].v2.values[(np.abs(df[df.v1==v].p.values - -4)).argmin()+1]
    o[i,3] = df[df.v1==v].p.values[(np.abs(df[df.v1==v].p.values - -4)).argmin()]
    o[i,4] = df[df.v1==v].p.values[(np.abs(df[df.v1==v].p.values - -4)).argmin()+1]

# %%
df = pd.read_table(r'C:\Users\Ouyang Group\Documents\Data\8-5-16\wavetek power calibration double sweep')
o2 = np.empty((np.unique(df.v1).shape[0],5))
for i,v in enumerate(np.unique(df.v1)):
    plt.plot(df[df.v1==v].v2,df[df.v1==v].p,'o:')
    o2[i,0] = v
    o2[i,1] = df[df.v1==v].v2.values[(np.abs(df[df.v1==v].p.values - -4)).argmin()]
    o2[i,2] = df[df.v1==v].v2.values[(np.abs(df[df.v1==v].p.values - -4)).argmin()+1]
    o2[i,3] = df[df.v1==v].p.values[(np.abs(df[df.v1==v].p.values - -4)).argmin()]
    o2[i,4] = df[df.v1==v].p.values[(np.abs(df[df.v1==v].p.values - -4)).argmin()+1]

# %%
plt.plot(o[:,0],o[:,4],'ro:')
plt.plot(o2[:,0],o2[:,3],'ko:')

# %%
plt.plot(o2[:,0],o2[:,1],'ko:')
from scipy.interpolate import interp1d
f2 = interp1d(o2[:,0],o2[:,1], kind='cubic')
xnew = np.arange(0.22,9.9,0.001)
plt.plot(xnew,f2(xnew),'r-')
np.savetxt(r'C:\Users\Ouyang Group\Documents\Data\8-5-16\wavetek power calibration double sweep -4dbm interp 3',np.column_stack((xnew,f2(xnew))),fmt='%5f')
np.savetxt(r'C:\Users\Ouyang Group\Documents\Data\8-5-16\wavetek power calibration double sweep -4dbm raw 3',np.column_stack((o2[:,0],o2[:,1])),fmt='%5f')

# %%
plt.plot(o[:,0],o[:,3],'ko:')
plt.plot(o[:,0],o[:,4],'ro:')

# %%
p = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-1-16\MW power sweep to amp 10 leveled')
p2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-1-16\MW power sweep to amp 11 leveled')
p3 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-1-16\MW power sweep to amp 12 leveled')

plt.plot(p[2:,1],p[2:,2],'ro:')
plt.plot(p2[2:,1],p2[2:,2],'go:')
plt.plot(p3[2:,1],p3[2:,2],'bo:')

# %%
p = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-28-16\freq and power sweep from sampler with leveling')
plt.plot(p[2:,1],p[2:,2],'ko:')

# %%
od1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-29-16\MNP wash 2 on CPW 5mW ODMR scan 1 x111 y57 old amp')
od2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-29-16\MNP wash 2 on CPW 5mW ODMR scan 2 x11 y56 new amp')

plt.plot(od1[2:,0],od1[2:,1])
plt.plot(od2[2:,0],od2[2:,1])

# %%
p1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-30-16\MW linear power sweep two power 10V high res')
np.savetxt(r'C:\Users\Ouyang Group\Documents\Data\8-1-16\sampler to amp difference',np.column_stack((p1[8:,1],p1[8:,0]-p1[8:,3])),fmt='%5f')

plt.plot(p1[8:,1],p1[8:,0]-p1[8:,3],'ko:')

# %%
plt.plot(p1[8:,1],p1[8:,3],'bo:')
plt.plot(p1[8:,1],p1[8:,0],'ro:')

# %%
test = p1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-1-16\MNP 2 on CPW 5mW ODMR can 2 x71 y119 old amp leveled power 2')

plt.plot(test[test[:,2]>-200][:,0],test[test[:,2]>-200][:,2])
plt.plot(test[test[:,2]>-200][:,0],test[test[:,2]>-200][:,1])

# %%
p1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-2-16\new amplifier power stability over time 24db attenuation 3')

plt.plot(p1[2:,1],p1[2:,0]+24,'k-',linewidth=2)
plt.ylim([20,30])
#plt.xlim([0,1200])
plt.xlabel('time (s)')
plt.ylabel('power (dbm)')

# %%
p2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-2-16\wavetek power stability over time 3')

plt.plot(p2[2:,1],p2[2:,0],'k-',linewidth=2)
plt.xlabel('time (s)')
plt.ylabel('power (dbm)')

# %%
p = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-5-16\wavetek power leveled sweep')
plt.plot(p[2:,1],p[2:,2],'ro:')

p2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-5-16\wavetek power leveled sweep 2')
plt.plot(p2[2:,1],p2[2:,2],'ko:')

p3 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-5-16\wavetek amplifier power leveled sweep')
plt.plot(p3[2:,1],p3[2:,2],'ko:')

# %%
plt.plot(p3[2:,1],p3[2:,2]+24,'ko:')

# %%
p = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-22-16\max power mw sweep with 6db attenuator')
plt.plot(p[:,1],p[:,2],'ro:')

p2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\8-22-16\max power mw sweep with 6db attenuator 2')
plt.plot(p2[:,1],p2[:,2],'ko:')
plt.xlim([2.5E9,3E9])
plt.ylim([-6,-2])
# Out:
# (-6, -2)

# %%
t = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\9-23-16\MNP 3 CPW transmission -9dbm')
t2 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\9-23-16\MNP 3 wire transmission -9dbm')

# %%
plt.plot(t[:,1],t[:,2])
plt.plot(t2[:,1],t2[:,2])

# %%
plt.plot(t[:,1],t[:,2]-t2[1:,2])
