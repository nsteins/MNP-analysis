# %%
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8
from NV import *

# %%
T1 = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\12-16-16\MNP 11-3-B on CPW 0.5mW scan 12 x132 y168 rotor sweep')
T1[:,1] -= 1500
OrientPol(T1,False)
# Out:
# Phi: 58.542169 +/- 0.782413
# Theta: 46.376125 or +/- 0.627508
# Phi(naive): 55.618000
# Theta(naive): 52.601139

# %%
time,rabi0 = EPR_NoRef(r'C:\Users\Ouyang Group\Documents\Data\12-16-16\MNP 11-3-B on CPW 0.5mW scan 12 x132 y168 B0.29V T58 d6.7 th 46 rabi *[3-9]',
              r'C:\Users\Ouyang Group\Documents\Data\12-16-16\MNP 11-3-B on CPW 0.5mW scan 12 x132 y168 B0.29V T58 d6.7 th 46 rabi Pulse Seq')
#rabi0 = 100*rabi0/np.mean(rabi0)
opt0,cov0 = curve_fit(RabiFit,time[1:],rabi0[1:],maxfev=5500,p0=(100,14E-3,0,1200,900))
t = np.arange(0,np.max(time),1)
plt.plot(time,rabi0,'ko:')
plt.plot(t,RabiFit(t,*opt0),'b-')
print opt0
# Out:
# [ -7.26558294e+00   1.47152487e-02  -4.51662852e+00  -1.00793969e+05
#    7.84767221e+02]

# %%
time,rabi0 = EPR_NoRef(r'C:\Users\Ouyang Group\Documents\Data\12-16-16\MNP 11-3-B on CPW 0.5mW scan 12 x132 y168 B0.29V T58 d6.7 th 46 2 rabi *[0-9]',
              r'C:\Users\Ouyang Group\Documents\Data\12-16-16\MNP 11-3-B on CPW 0.5mW scan 12 x132 y168 B0.29V T58 d6.7 th 46 rabi Pulse Seq')
#rabi0 = 100*rabi0/np.mean(rabi0)
opt0,cov0 = curve_fit(RabiFit,time[1:],rabi0[1:],maxfev=5500,p0=(100,14E-3,0,1200,900))
t = np.arange(0,np.max(time),1)
plt.plot(time,rabi0,'ko:')
plt.plot(t,RabiFit(t,*opt0),'b-')
print opt0
# Out:
# [ -7.65647646e+00   1.45216635e-02  -1.52676935e+00  -2.31739227e+05
#    7.59050170e+02]

# %%
def T1Fit(t,I_inf,C_m,T_m,C_1,T_1):
         return I_inf * (1 - C_m*np.exp(-t/T_m) + C_1*np.exp(-t/T_1))
    
time,T0 = EPR(r'C:\Users\Ouyang Group\Documents\Data\12-16-16\MNP 11-3-B on CPW 0.5mW scan 12 t1 x128 y169 T1 7200 sec *[0-9]',
         r'C:\Users\Ouyang Group\Documents\Data\12-16-16\MNP 11-3-B on CPW 0.5mW scan 12 t1 x128 y169 T1 7200 sec  Pulse Seq')
time = time+20
T0 = T0 - np.min(T0)
opt0,cov0 = curve_fit(T1Fit,time[1:],T0[1:],maxfev=5500,p0=(0,0.1,200,0.2,1000))
t = np.logspace(1,6,200)
plt.semilogx(t,T1Fit(t,*opt0),'b-')
print opt0
plt.semilogx(time,T0,'ko:')
# Out:
# [  9.81208447e+00   9.18154418e+00   3.62762387e+02   1.64074036e+01
#    2.12607252e+04]
