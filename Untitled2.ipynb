# %%
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8
from NV import *

# %%
t = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\6-24-16\MNP on CPW 0.5mw scan 3 x166 y80 rotor scan 2')
t[:,1] = t[:,1]-900
OrientPol(t)
# Out:
# Phi: 31.220311 +/- 0.593233
# Theta: 47.236340 or +/- 0.488068
# Phi(naive): 27.303000
# Theta(naive): 51.536074

# %%
t = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\6-24-16\MNP on CPW 0.5mw scan 3 x166 y80 rotor scan 1')
t[:,1] = t[:,1]-900
OrientPol(t)
# Out:
# Phi: 36.478670 +/- 0.486431
# Theta: 42.017721 or +/- 0.350511
# Phi(naive): 35.393000
# Theta(naive): 44.376126

# %%
t = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\6-24-16\MNP on CPW 1mw scan 3 x166 y80 rotor scan 1')
t[:,1] = t[:,1]-1200
OrientPol(t)
# Out:
# Phi: 35.043899 +/- 0.388482
# Theta: 44.633180 or +/- 0.299329
# Phi(naive): 35.393000
# Theta(naive): 47.790596

# %%
t = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\6-24-16\MNP on CPW 3.5mw scan 3 x166 y80 rotor scan 1')
t[:,1] = t[:,1]-1200*3.5
OrientPol(t)
# Out:
# Phi: 41.453929 +/- 1.172842
# Theta: 31.029712 or +/- 0.622064
# Phi(naive): 35.393000
# Theta(naive): 36.402059

# %%
t = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\6-24-16\MNP on CPW 0.35mw scan 3 x166 y80 rotor scan 2')
t[:,1] = t[:,1]-800
OrientPol(t)
# Out:
# Phi: 31.894821 +/- 0.361697
# Theta: 50.781583 or +/- 0.326836
# Phi(naive): 35.393000
# Theta(naive): 53.917902

# %%
f = np.loadtxt(r'C:\Users\Ouyang Group\Documents\Data\7-30-16\RF linear power sweep 0dbm output')
plt.plot(f[:,1],f[:,0])
